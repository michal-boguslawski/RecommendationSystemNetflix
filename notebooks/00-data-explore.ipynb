# %% [markdown]
# # Data exploration of Netflix move dataset
# https://www.kaggle.com/datasets/netflix-inc/netflix-prize-data

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd

# %% [markdown]
# ## Load sample data

# %%
data_path = "../data/raw/combined_data_1.txt"
with open(data_path, "r") as f:
    i = 0
    while i < 5:
        print(f.readline())
        i += 1
# Out:
# 1:
#
# 1488844,3,2005-09-06
#
# 822109,5,2005-05-13
#
# 885013,4,2005-10-19
#
# 30878,4,2005-12-26
